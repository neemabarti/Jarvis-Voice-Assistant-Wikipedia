# %%
import pyttsx3
import datetime
import speech_recognition as sr
import pyaudio

# %%
engine = pyttsx3.init('sapi5')
voices = engine.getProperty('voices')
print(voices[1].id)
engine.setProperty('voice',voices[1].id)
 
def speak(audio):
    engine.say(audio)
    engine.runAndWait()
   
def wishMe():
    hour = int(datetime.datetime.now().hour)
    if hour>=0 and hour<12:
           speak("good morning1!")
           

    elif  hour>=12 and hour<18:
           speak("good afternoon!")
    else:      
            speak("good evening!")
           
    speak("iam jarvis how can i help you")       
           
if __name__ == "__main__":
    speak(" i am a good girl")
wishMe()
# Out:
# HKEY_LOCAL_MACHINE\SOFTWARE\Microsoft\Speech\Voices\Tokens\TTS_MS_EN-US_ZIRA_11.0

# %%
import speech_recognition as sr
for index , name in enumerate(sr.Microphone.list_microphone_names()):
     print(f"Microphone with index {index} is named {name}")
# Out:
# Microphone with index 0 is named Microsoft Sound Mapper - Input
# Microphone with index 1 is named Microphone Array (IntelÂ® Smart
# Microphone with index 2 is named Microsoft Sound Mapper - Output
# Microphone with index 3 is named Speakers (Realtek(R) Audio)
# Microphone with index 4 is named Primary Sound Capture Driver
# Microphone with index 5 is named Microphone Array (IntelÂ® Smart Sound Technology (IntelÂ® SST))
# Microphone with index 6 is named Primary Sound Driver
# Microphone with index 7 is named Speakers (Realtek(R) Audio)
# Microphone with index 8 is named Speakers (Realtek(R) Audio)
# Microphone with index 9 is named Microphone Array (IntelÂ® Smart Sound Technology (IntelÂ® SST))
# Microphone with index 10 is named Microphone 1 (Realtek HD Audio Mic input with SST)
# Microphone with index 11 is named Microphone 2 (Realtek HD Audio Mic input with SST)
# Microphone with index 12 is named Microphone 3 (Realtek HD Audio Mic input with SST)
# ...

# %%
 import speech_recognition as sr
for index , name in enumerate(sr.Microphone.list_microphone_names()):
     print(f"Microphone with index {index} is named {name}")
recognizer= sr.Recognizer()
with sr.Microphone(device_index=1) as source: 
    print("Adjusting for ambient noise... Please wait.")
    recognizer.adjust_for_ambient_noise(source, duration=2)
    print("Listening... (timeout in 5 seconds)")

    try:
        # Capture audio with a 5-second timeout
        audio = recognizer.listen(source, timeout=5, phrase_time_limit=10)
        
        # Recognize the speech using Google Web Speech API
        text = recognizer.recognize_google(audio)
        print("You said:", text)
        
    except sr.WaitTimeoutError:
        print("Timeout: No speech detected within 5 seconds.")
    except sr.UnknownValueError:
        print("Sorry, I couldn't understand the audio.")
    except sr.RequestError:
        print("Could not request results from Google Speech Recognition service; check your network connection.")
# Out:
# Microphone with index 0 is named Microsoft Sound Mapper - Input
# Microphone with index 1 is named Microphone Array (IntelÂ® Smart
# Microphone with index 2 is named Microsoft Sound Mapper - Output
# Microphone with index 3 is named Speakers (Realtek(R) Audio)
# Microphone with index 4 is named Primary Sound Capture Driver
# Microphone with index 5 is named Microphone Array (IntelÂ® Smart Sound Technology (IntelÂ® SST))
# Microphone with index 6 is named Primary Sound Driver
# Microphone with index 7 is named Speakers (Realtek(R) Audio)
# Microphone with index 8 is named Speakers (Realtek(R) Audio)
# Microphone with index 9 is named Microphone Array (IntelÂ® Smart Sound Technology (IntelÂ® SST))
# Microphone with index 10 is named Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(pTron BT))
# Microphone with index 11 is named Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(pTron BT))
# Microphone with index 12 is named Headphones ()
# ...

# %%
import wikipedia
import pyttsx3
import speech_recognition as sr


def take_command():
    
    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening for your command...")
        recognizer.pause_threshold = 1
        audio = recognizer.listen(source)
    try:
        print("Recognizing...")
        query = recognizer.recognize_google(audio, language='en-in')
        print(f"You said: {query}\n")
    except Exception as e:
        print("Could not understand. Please say that again.")
        return None
    return query.lower()

def search_wikipedia(query):
    try:
        results = wikipedia.summary(query, sentences=2)  # Limit the summary to 2 sentences
        speak("According to Wikipedia")
        speak(results)
        print(results)
    except wikipedia.exceptions.DisambiguationError as e:
        speak("The term is ambiguous, please be more specific.")
        print("Disambiguation error:", e)
    except wikipedia.exceptions.PageError:
        speak("I couldn't find any results for that term.")
        print("Page not found.")

# %%
import wikipedia
import pyttsx3
import speech_recognition as sr

# Initialize the text-to-speech engine
engine = pyttsx3.init('sapi5')
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[1].id)

def speak(audio):
    """Convert text to speech."""
    engine.say(audio)
    engine.runAndWait()

def take_command():
    """Listen to the user's voice command and return it as text."""
    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening for your command...")
        recognizer.pause_threshold = 1
        audio = recognizer.listen(source)
    try:
        print("Recognizing...")
        query = recognizer.recognize_google(audio, language='en-in')
        print(f"You said: {query}\n")
    except Exception as e:
        print("Could not understand. Please say that again.")
        return None
    return query.lower()

def search_wikipedia(query):
    """Search Wikipedia for the given query and provide a spoken summary."""
    try:
        results = wikipedia.summary(query, sentences=5)  # Limit the summary to 2 sentences
        speak("According to Wikipedia")
        speak(results)
        print(results)
    except wikipedia.exceptions.DisambiguationError as e:
        speak("The term is ambiguous, please be more specific.")
        print("Disambiguation error:", e)
    except wikipedia.exceptions.PageError:
        speak("I couldn't find any results for that term.")
        print("Page not found.")
    except Exception as e:
        speak("An error occurred while fetching information.")
        print("Error:", e)

def main():
    """Main function to handle taking commands and searching Wikipedia."""
    while True:
        query = take_command()
        if query:
            if "wikipedia" in query:
                search_term = query.replace("wikipedia", "").strip()
                if search_term:
                    search_wikipedia(search_term)
                else:
                    speak("Please specify what you want to search on Wikipedia.")
            elif "exit" in query or "stop" in query:
                speak("Goodbye!")
                break

if __name__ == "__main__":
    main()
# Out:
# Listening for your command...
# Recognizing...
# Could not understand. Please say that again.
# Listening for your command...
# Recognizing...
# Could not understand. Please say that again.
# Listening for your command...
# Recognizing...
# You said: tell me something
#
# Listening for your command...
# Recognizing...
# You said: about Shahrukh Khan from Wikipedia
#
# ...
